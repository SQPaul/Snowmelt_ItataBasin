# %% [markdown]
# # Sentinel2
# ## Snowrunoff - february, 2023
# ##### Paul Sandoval Quilodrán - https://github.com/SQPaul

# %%
from sentinel2 import sentinel2

# %%
mask = r"P:\Projects\Olivares\Fieldwork\mask.gpkg"
sentinel2(mask,20,"2023-01-10","2023-01-31")
# Out:
# Lista de imágenes disponibles:
#                      nubosidad                                      id  year  \
# fecha
# 2023-01-13 15:42:40   0.029675  20230113T143719_20230113T144449_T19HCC  2023
# 2023-01-13 15:42:40   0.000312  20230113T143719_20230113T144449_T19HCD  2023
# 2023-01-13 15:42:40   0.002931  20230113T143719_20230113T144449_T19HDC  2023
# 2023-01-13 15:42:40   3.768404  20230113T143719_20230113T144449_T19HDD  2023
# 2023-01-15 16:10:54   2.562149  20230115T142711_20230115T144040_T19HCC  2023
# 2023-01-15 16:10:54   2.884740  20230115T142711_20230115T144040_T19HCD  2023
# 2023-01-18 17:33:02   0.039549  20230118T143721_20230118T144030_T19HCC  2023
# 2023-01-18 17:33:02   0.342597  20230118T143721_20230118T144030_T19HCD  2023
# 2023-01-18 17:33:02   0.218713  20230118T143721_20230118T144030_T19HDC  2023
# 2023-01-18 17:33:02   7.545372  20230118T143721_20230118T144030_T19HDD  2023
# 2023-01-20 15:40:34   0.048514  20230120T142709_20230120T143451_T19HCC  2023
# ...
